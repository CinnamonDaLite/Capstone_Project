# %% [markdown]
# ### This is the testing section for the project

# %%
#gathering libraries for next data set that will be imported from R

#Taking Vaxcine report data

#The purpose of this script is to take the VAERS Data
#Access multiple datasets as necessary and cleanup the datasets
#by merging into one, cleaner dataset

#Importing nessecery libraries
import numpy as np
import pandas as pd

# %%
#vax_data_2021 will take a while, there is a lot of information in there
#used low_memory = False argument to speed up the process as warned
#needed to chage the engoding to fix the encoding problem

vax_data_2021 = pd.read_csv('2021VAERSDATA.csv', low_memory = False , encoding="iso-8859-1")
vax_types_2021 = pd.read_csv('2021VAERSVAX.csv', low_memory = False , encoding="iso-8859-1")

# %%
vax_data_2021
# Out:
#         VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0         916600  01/01/2021    TX     33.0     33.0      NaN   F      NaN
# 1         916601  01/01/2021    CA     73.0     73.0      NaN   F      NaN
# 2         916602  01/01/2021    WA     23.0     23.0      NaN   F      NaN
# 3         916603  01/01/2021    WA     58.0     58.0      NaN   F      NaN
# 4         916604  01/01/2021    TX     47.0     47.0      NaN   F      NaN
# ...          ...         ...   ...      ...      ...      ...  ..      ...
# 721465   1939059  12/10/2021    IL     40.0     40.0      NaN   F      NaN
# 721466   1939060  12/10/2021    ME     48.0     48.0      NaN   F      NaN
# 721467   1939061  12/10/2021    IN     46.0     46.0      NaN   M      NaN
# 721468   1939062  12/10/2021    ME     75.0     75.0      NaN   M      NaN
# 721469   1939063  12/10/2021    CA     39.0     39.0      NaN   F      NaN
#
#                                              SYMPTOM_TEXT DIED  ...  \
# 0       Right side of epiglottis swelled up and hinder...  NaN  ...
# 1       Approximately 30 min post vaccination administ...  NaN  ...
# 2       About 15 minutes after receiving the vaccine, ...  NaN  ...
# 3       extreme fatigue, dizziness,. could not lift my...  NaN  ...
# 4       Injection site swelling, redness, warm to the ...  NaN  ...
# ...                                                   ...  ...  ...
# 721465  My S/S occured <24hrs, right breast doubled in...  NaN  ...
# 721466                   Error: Incorrect Reconstitution-  NaN  ...
# 721467              Swollen lymph node under same armpit.  NaN  ...
# 721468                   Error: Incorrect Reconstitution-  NaN  ...
# 721469  Facial and neck swelling for 45 min after firs...  NaN  ...
#
#                                                   CUR_ILL  \
# 0                                                    None
# 1       Patient residing at nursing facility. See pati...
# 2                                                    None
# 3                                        kidney infection
# 4                                                      Na
# ...                                                   ...
# 721465                                         none noted
# 721466                                                NaN
# 721467                                                NaN
# 721468                                                NaN
# 721469                                                 No
#
#                                                   HISTORY  \
# 0                                                    None
# 1       Patient residing at nursing facility. See pati...
# 2                                                    None
# 3       diverticulitis, mitral valve prolapse, osteoar...
# 4                                                     NaN
# ...                                                   ...
# 721465                                Anxiety, depression
# 721466                                                NaN
# 721467                                                NaN
# 721468                                                NaN
# 721469                                                 No
#
#                                                 PRIOR_VAX SPLTTYPE  FORM_VERS  \
# 0                                                     NaN      NaN          2
# 1                                                     NaN      NaN          2
# 2                                                     NaN      NaN          2
# 3       got measles from measel shot, mums from mumps ...      NaN          2
# 4                                                     NaN      NaN          2
# ...                                                   ...      ...        ...
# 721465                                                NaN      NaN          2
# 721466                                                NaN      NaN          2
# 721467                                                NaN      NaN          2
# 721468                                                NaN      NaN          2
# 721469                                                NaN      NaN          2
#
#        TODAYS_DATE BIRTH_DEFECT OFC_VISIT ER_ED_VISIT  \
# 0       01/01/2021          NaN         Y         NaN
# 1       01/01/2021          NaN         Y         NaN
# 2       01/01/2021          NaN       NaN           Y
# 3       01/01/2021          NaN       NaN         NaN
# 4       01/01/2021          NaN       NaN         NaN
# ...            ...          ...       ...         ...
# 721465  12/10/2021          NaN         Y           Y
# 721466  12/10/2021          NaN       NaN         NaN
# 721467  12/10/2021          NaN       NaN         NaN
# 721468  12/10/2021          NaN       NaN         NaN
# 721469  12/10/2021          NaN       NaN         NaN
#
#                                                 ALLERGIES
# 0                                       Pcn and bee venom
# 1                                                 "Dairy"
# 2                                               Shellfish
# 3       Diclofenac, novacaine, lidocaine, pickles, tom...
# 4                                                      Na
# ...                                                   ...
# 721465                                               none
# 721466                                                NaN
# 721467                                                NaN
# 721468                                                NaN
# 721469                                          Shellfish
#
# [721470 rows x 35 columns]

# %%
vax_types_2021
# Out:
#         VAERS_ID VAX_TYPE              VAX_MANU  VAX_LOT VAX_DOSE_SERIES  \
# 0         916600  COVID19               MODERNA  037K20A               1
# 1         916601  COVID19               MODERNA  025L20A               1
# 2         916602  COVID19       PFIZER\BIONTECH   EL1284               1
# 3         916603  COVID19               MODERNA  unknown             UNK
# 4         916604  COVID19               MODERNA      NaN               1
# ...          ...      ...                   ...      ...             ...
# 762757   1939089     FLU4        SANOFI PASTEUR  UJ50GAA               1
# 762758   1939102  COVID19       PFIZER\BIONTECH    FC183               2
# 762759   1939113  COVID19       PFIZER\BIONTECH   EC3182               1
# 762760   1939114      UNK  UNKNOWN MANUFACTURER      NaN             UNK
# 762761   1939125      UNK  UNKNOWN MANUFACTURER      NaN             UNK
#
#        VAX_ROUTE VAX_SITE                                     VAX_NAME
# 0             IM       LA                  COVID19 (COVID19 (MODERNA))
# 1             IM       RA                  COVID19 (COVID19 (MODERNA))
# 2             IM       LA          COVID19 (COVID19 (PFIZER-BIONTECH))
# 3            NaN      NaN                  COVID19 (COVID19 (MODERNA))
# 4             IM       LA                  COVID19 (COVID19 (MODERNA))
# ...          ...      ...                                          ...
# 762757       NaN       AR  INFLUENZA (SEASONAL) (FLUZONE QUADRIVALENT)
# 762758        IM       LA          COVID19 (COVID19 (PFIZER-BIONTECH))
# 762759        IM       RA          COVID19 (COVID19 (PFIZER-BIONTECH))
# 762760       NaN      NaN                VACCINE NOT SPECIFIED (OTHER)
# 762761       NaN      NaN                VACCINE NOT SPECIFIED (OTHER)
#
# [762762 rows x 8 columns]

# %%
#In the testing portion, I created a new variable. But after testing it and seeing how it worked,
#I save back the same dataframe after determining what variables/columns I need
vax_data_2021 = vax_data_2021.drop(['RPT_DATE', 'TODAYS_DATE', 'CAGE_YR', 'SPLTTYPE', 'OFC_VISIT', 
                                    'ER_ED_VISIT', 'FORM_VERS', 'DATEDIED', 'ER_VISIT', 'HOSPDAYS', 
                                    'X_STAY', 'ONSET_DATE', 'NUMDAYS', 'LAB_DATA', 'V_FUNDBY', 
                                    'V_ADMINBY', 'PRIOR_VAX', 'CAGE_MO', 'VAX_DATE', 'OTHER_MEDS',
                                    'CUR_ILL', 'HISTORY', 'BIRTH_DEFECT', 'ALLERGIES'], 1)
                                    
vax_types_2021 = vax_types_2021.drop(['VAX_LOT','VAX_DOSE_SERIES','VAX_ROUTE','VAX_SITE',
                                      'VAX_NAME'],1)

# %%
#Merging them to fix the data to my likeing
vax_info_2021 = pd.merge(vax_types_2021, vax_data_2021, on = 'VAERS_ID')

# %%
#Fix the missing values by the context of the problem
#NaN for Birth_Defects = no birth defects
#NaN for DIED = N
#NaN for PRIOR_VAX = No affirmities
null_col = {'DIED':'N', 'L_THREAT':'N', 'HOSPITAL':'N', 'DISABLE':'N', 'RECOVD':'U', 'STATE':'US'}
vax_info_2021 = vax_info_2021.fillna(value = null_col)

vax_info_2021 = vax_info_2021.dropna()
# Out:
#         VAX_TYPE        VAX_MANU   RECVDATE STATE   AGE_YRS SEX L_THREAT DIED  \
# 0        COVID19         MODERNA 2021-08-15    FL   over 50   F        N    N
# 1        COVID19         MODERNA 2021-08-15    FL   over 50   F        N    N
# 2        COVID19         MODERNA 2021-08-22    FL   over 50   F        N    N
# 3        COVID19         MODERNA 2021-08-22    CA   over 50   F        N    N
# 4        COVID19         MODERNA 2021-08-15    FL   over 50   F        N    N
# ...          ...             ...        ...   ...       ...  ..      ...  ...
# 1039447       YF  SANOFI PASTEUR 2021-11-12    SC  under 18   M        N    N
# 1039448       YF  SANOFI PASTEUR 2021-11-17    NM  18 to 35   M        N    N
# 1039449       YF  SANOFI PASTEUR 2021-11-17    NM  18 to 35   M        N    N
# 1039450       YF  SANOFI PASTEUR 2021-11-17    NM  18 to 35   M        N    N
# 1039451       YF  SANOFI PASTEUR 2021-11-17    NM  18 to 35   M        N    N
#
#         SYMPTOM_TEXT  Count
# 0           headache    814
# 1               rash    659
# 2           headache    638
# 3           headache    599
# 4             chills    583
# ...              ...    ...
# 1039447        hives      1
# 1039448        hives      1
# 1039449    itchiness      1
# 1039450         numb      1
# 1039451      redness      1
#
# [1039452 rows x 10 columns]

# %%
#Save it back to a csv file to be read by Rstudio
vax_info_2021.to_csv('VaxReports.csv')
